# %% [markdown]
# # Decision Tree

# %% [markdown]
# ### Assignment
# ### About the data: Let’s consider a Company dataset with around 10 variables and 400 records. The attributes are as follows:
# - Sales -- Unit sales (in thousands) at each location
# - Competitor Price -- Price charged by competitor at each location
# - Income -- Community income level (in thousands of dollars)
# - Advertising -- Local advertising budget for company at each location (in thousands of dollars)
# - Population -- Population size in region (in thousands)
# - Price -- Price company charges for car seats at each site
# - Shelf Location at stores -- A factor with levels Bad, Good and Medium indicating the quality of the shelving location for the car seats at each site
# - Age -- Average age of the local population
# - Education -- Education level at each location
# - Urban -- A factor with levels No and Yes to indicate whether the store is in an urban or rural location
# - US -- A factor with levels No and Yes to indicate whether the store is in the US or not

# %% [markdown]
# ### Problem Statement:
# - A cloth manufacturing company is interested to know about the segment or attributes causes high sale. Approach - A decision tree can be built with target variable Sale (we will first convert it in categorical variable) & all other variable will be independent in the analysis.

# %% [markdown]
# ### Import Required Packages

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### Load the Dataset

# %%
df = pd.read_csv("./Company_Data.csv")

# %% [markdown]
# ### EDA

# %%
df.sample(n=6)
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 352  13.44        133     103           14         288    122      Good   61
# 41    7.96        157      53            0         403    124       Bad   58
# 230   5.16        115      60            0         119    114       Bad   38
# 153   5.93        150      36            7         488    150    Medium   25
# 216   5.73        141      33            0         243    144    Medium   34
# 157  10.21        121      58            8         249     90    Medium   48
#
#      Education Urban   US
# 352         17   Yes  Yes
# 41          16   Yes   No
# 230         14    No   No
# 153         17    No  Yes
# 216         17   Yes   No
# 157         13    No  Yes

# %%
# get general info
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    str
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    str
#  10  US           400 non-null    str
# dtypes: float64(1), int64(7), str(3)
# memory usage: 38.5 KB

# %%
# get statistical info
df.describe()
# Out:
#             Sales   CompPrice      Income  Advertising  Population  \
# count  400.000000  400.000000  400.000000   400.000000  400.000000
# mean     7.496325  124.975000   68.657500     6.635000  264.840000
# std      2.824115   15.334512   27.986037     6.650364  147.376436
# min      0.000000   77.000000   21.000000     0.000000   10.000000
# 25%      5.390000  115.000000   42.750000     0.000000  139.000000
# 50%      7.490000  125.000000   69.000000     5.000000  272.000000
# 75%      9.320000  135.000000   91.000000    12.000000  398.500000
# max     16.270000  175.000000  120.000000    29.000000  509.000000
#
#             Price         Age   Education
# count  400.000000  400.000000  400.000000
# mean   115.795000   53.322500   13.900000
# std     23.676664   16.200297    2.620528
# min     24.000000   25.000000   10.000000
# 25%    100.000000   39.750000   12.000000
# 50%    117.000000   54.500000   14.000000
# 75%    131.000000   66.000000   16.000000
# ...

# %%
# check if there is any missing records
df.isna().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
# check if there is any missing records
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(8,5))

plt.hist(df["Sales"], bins=20, color="lightgreen", edgecolor="black")

# Draw vertical lines
plt.axvline(df["Sales"].min(), color="red", linestyle="--", label=f"Min = {df['Sales'].min():.2f}")
plt.axvline(df["Sales"].max(), color="blue", linestyle="--", label=f"Max = {df['Sales'].max():.2f}")

plt.title("Distribution of Sales")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.legend()
plt.grid(True)

plt.show()

# %%
# create copy of original because orginal stay as it is if we change in copy
df1 = df.copy()

# %%
df1['Sales_cat'] = pd.qcut(
    df1['Sales'],
    q=3,
    labels=['Low','Medium','High']
)

# %%
df1.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120       Bad   42
# 1  11.22        111      48           16         260     83      Good   65
# 2  10.06        113      35           10         269     80    Medium   59
# 3   7.40        117     100            4         466     97    Medium   55
# 4   4.15        141      64            3         340    128       Bad   38
#
#    Education Urban   US Sales_cat
# 0         17   Yes  Yes      High
# 1         10   Yes  Yes      High
# 2         12   Yes  Yes      High
# 3         14   Yes  Yes    Medium
# 4         13   Yes   No       Low

# %%
# convert Urban into numerical
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df1["Urban"] = le.fit_transform(df1["Urban"])

# %%
# convert US into numerical
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df1["US"] = le.fit_transform(df1["US"])

# %%
# convert ShelveLoc into numerical
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df1["ShelveLoc"] = le.fit_transform(df1["ShelveLoc"])

# %%
# convert Sales_cat into numerical
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df1["Sales_cat"] = le.fit_transform(df1["Sales_cat"])

# %%
df1.head()
# Out:
#    Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0   9.50        138      73           11         276    120          0   42
# 1  11.22        111      48           16         260     83          1   65
# 2  10.06        113      35           10         269     80          2   59
# 3   7.40        117     100            4         466     97          2   55
# 4   4.15        141      64            3         340    128          0   38
#
#    Education  Urban  US  Sales_cat
# 0         17      1   1          0
# 1         10      1   1          0
# 2         12      1   1          0
# 3         14      1   1          2
# 4         13      1   0          1

# %%
corr = df1.corr(numeric_only=True)
corr["Sales_cat"].abs().sort_values(ascending=False)
# Out:
# Sales_cat      1.000000
# Sales          0.466075
# Price          0.188300
# Advertising    0.181982
# Age            0.134596
# US             0.117181
# Income         0.066064
# CompPrice      0.057440
# Population     0.053272
# ShelveLoc      0.030881
# Urban          0.017411
# Education      0.016165
# Name: Sales_cat, dtype: float64

# %%
# check if the dataset is balanced
df1['Sales_cat'].value_counts()
# Out:
# Sales_cat
# 2    134
# 1    134
# 0    132
# Name: count, dtype: int64

# %% [markdown]
# ### data preparation

# %%
# split the data into x and y 
x = df1.drop(["Sales", "Sales_cat","Income", "Population", "Education", "Urban", "US"],axis=1)
y = df1['Sales_cat']

# %%
# split the data into train and test
from sklearn.model_selection import  train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7,random_state=42,stratify=y)

# %% [markdown]
# ### train the models

# %%
from sklearn.tree import DecisionTreeClassifier

# Create the model
model = DecisionTreeClassifier(
   criterion="entropy",
   max_depth=4,
   min_samples_split=10,
   min_samples_leaf=5,
   random_state=42
)
'''
(
    criterion = 'gini',
    max_depth =  5,
    max_features = None,
    min_samples_leaf = 5,
    min_samples_split = 20
)
'''

# Train the model
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_leaf=5,
#                        min_samples_split=10, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier

# Create the model
model1 = RandomForestClassifier(
    n_estimators=100,
    criterion="entropy",
    max_depth=4,
    min_samples_split=10,
    min_samples_leaf=5,
    random_state=42
)

# Train the model
model1.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=4, min_samples_leaf=5,
#                        min_samples_split=10, random_state=42)

# %%
feature_importance = (
    pd.Series(model.feature_importances_, index=x_train.columns)
      .sort_values(ascending=False)
)

print(feature_importance)
# Out:
# ShelveLoc      0.404174
# Price          0.319713
# CompPrice      0.095374
# Age            0.090908
# Advertising    0.089831
# dtype: float64

# %%
param_grid = {
    "criterion": ["gini", "entropy"],
    "max_depth": [3, 4, 5, 6, 7, 8],
    "min_samples_split": [5, 10, 20],
    "min_samples_leaf": [2, 5, 10],
    "max_features": [None, "sqrt"]
}

# %%
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(
    estimator=model,
    param_grid=param_grid,
    cv=5,
    scoring="accuracy",
    n_jobs=-1
)

grid_search.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=DecisionTreeClassifier(criterion='entropy', max_depth=4,
#                                               min_samples_leaf=5,
#                                               min_samples_split=10,
#                                               random_state=42),
#              n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [3, 4, 5, 6, 7, 8],
#                          'max_features': [None, 'sqrt'],
#                          'min_samples_leaf': [2, 5, 10],
#                          'min_samples_split': [5, 10, 20]},
#              scoring='accuracy')

# %%
print("Best Parameters:")
print(grid_search.best_params_)
# Out:
# Best Parameters:
# {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'min_samples_leaf': 5, 'min_samples_split': 20}

# %%
best_model = grid_search.best_estimator_

# %% [markdown]
# ### evaluate the model

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
#predict the train model 
y_pred = model.predict(x_train)

accuracy = accuracy_score(y_train, y_pred)
precision = precision_score(y_train,y_pred,average="weighted")
recall = recall_score(y_train,y_pred,average="weighted")
f1 = f1_score(y_train,y_pred,average="weighted")

print(f"accuracy = {accuracy:.2f}")
print(f"precision = {precision:.2f}")
print(f"recall = {recall:.2f}")
print(f"f1 = {f1:.2f}")
# Out:
# accuracy = 0.68
# precision = 0.69
# recall = 0.68
# f1 = 0.65

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score
#predict the train model 
y_pred = model1.predict(x_train)

accuracy = accuracy_score(y_train, y_pred)
precision = precision_score(y_train,y_pred,average="weighted")
recall = recall_score(y_train,y_pred,average="weighted")
f1 = f1_score(y_train,y_pred,average="weighted")

print(f"accuracy = {accuracy:.2f}")
print(f"precision = {precision:.2f}")
print(f"recall = {recall:.2f}")
print(f"f1 = {f1:.2f}")
# Out:
# accuracy = 0.79
# precision = 0.79
# recall = 0.79
# f1 = 0.79

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# predict the test dataset
y_pred = model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred,average="weighted")
recall = recall_score(y_test, y_pred,average="weighted")
f1 = f1_score(y_test, y_pred,average="weighted")

print(f"accuracy = {accuracy:.2f}")
print(f"precision = {precision:.2f}")
print(f"recall = {recall:.2f}")
print(f"f1 = {f1:.2f}")
# Out:
# accuracy = 0.62
# precision = 0.63
# recall = 0.62
# f1 = 0.60

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# predict the test dataset
y_pred = model1.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred,average="weighted")
recall = recall_score(y_test, y_pred,average="weighted")
f1 = f1_score(y_test, y_pred,average="weighted")

print(f"accuracy = {accuracy:.2f}")
print(f"precision = {precision:.2f}")
print(f"recall = {recall:.2f}")
print(f"f1 = {f1:.2f}")
# Out:
# accuracy = 0.68
# precision = 0.67
# recall = 0.68
# f1 = 0.67
